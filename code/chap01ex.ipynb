# %% [markdown]
# Exercise from Think Stats, 2nd Edition (thinkstats2.com)<br>
# Allen Downey

# %%
import nsfg
df = nsfg.ReadFemPreg()
df
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 5           6         1        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# 8           7         1        NaN        NaN       NaN       NaN       5.0
# 9           7         2        NaN        NaN       NaN       NaN       5.0
# 10         12         1        NaN        NaN       NaN       NaN       5.0
# ...

# %% [markdown]
# Print value counts for <tt>birthord</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611933)

# %%
df.birthord.value_counts(sort=False, dropna = False)
# Out:
# NaN      4445
#  1.0     4413
#  2.0     2874
#  3.0     1234
#  4.0      421
#  5.0      126
#  6.0       50
#  7.0       20
#  8.0        7
#  9.0        2
#  10.0       1
# Name: birthord, dtype: int64

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
# %matplotlib inline
df.prglngth.hist(bins=20)

# %%
df.prglngth.value_counts()
# Out:
# 39    4744
# 40    1120
# 38     609
# 9      594
# 41     591
# 6      543
# 37     457
# 13     446
# 4      412
# 8      409
# 35     357
# 36     329
# 42     328
# 17     253
# 11     202
# 30     198
# 5      181
# 7      175
# 12     170
# 3      151
# 43     148
# 22     147
# 10     137
# 32     122
# 26     117
# 2       78
# 34      60
# 33      50
# 44      46
# 16      44
# 15      39
# 28      38
# 21      37
# 19      34
# 24      31
# 31      29
# 14      29
# 29      23
# 20      18
# 18      17
# 0       15
# 25      15
# 23      12
# 45      10
# 1        9
# 27       8
# 48       7
# 50       2
# 46       1
# 47       1
# Name: prglngth, dtype: int64

# %%
print len(df[df.prglngth <= 13])
print len(df[(df.prglngth >= 14) & (df.prglngth <= 26)])
print len(df[df.prglngth >= 27 ])
# Out:
# 3522
# 793
# 9278

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.hist(bins = 20)

# %%
print df.agepreg.isnull().sum()
print len(df[df.agepreg <= 19.99])
print len(df[(df.agepreg >= 20) & (df.agepreg <= 24.99)])
print len(df[(df.agepreg >= 25) & (df.agepreg <= 29.99)])
print len(df[(df.agepreg >= 30) & (df.agepreg <= 44.99)])
# Out:
# 352
# 3182
# 4246
# 3178
# 2635

# %% [markdown]
# Compute the mean birthweight.

# %%
df.totalwgt_lb.mean()
# Out:
# 7.265628457623368

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = 0.4536 * df['totalwgt_lb']

df.totalwgt_kg.mean()
# Out:
# 3.2956890683779663

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %% [markdown]
# [agecon](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=&subSec=8016&srtLabel=611937)
# * Age at time of conception
#
# [Attributes and methods for pandas Series](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html)

# %%
df.agecon /= 100

# %%
df.agecon.hist(bins = 20)

# %%
df.agecon.describe()
# Out:
# count    13593.000000
# mean        24.207098
# std          5.836915
# min          9.910000
# 25%         19.580000
# 50%         23.410000
# 75%         28.250000
# max         44.080000
# Name: agecon, dtype: float64

# %%
df.agecon.nunique()
# Out:
# 380

# %%
df.agecon.nsmallest(100).hist()

# %%
df.agecon.nlargest(100).hist()

# %% [markdown]
# Create a boolean Series.

# %%
df.outcome == 1
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13       False
# 14       False
# 15        True
# 16        True
# 17        True
# 18       False
# 19        True
# 20        True
# 21        True
# 22       False
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 13563     True
# 13564     True
# 13565     True
# 13566     True
# 13567    False
# 13568    False
# 13569     True
# 13570     True
# 13571     True
# 13572     True
# 13573     True
# 13574     True
# 13575    False
# 13576     True
# 13577    False
# 13578     True
# 13579     True
# 13580    False
# 13581     True
# 13582    False
# 13583    False
# 13584     True
# 13585    False
# 13586    False
# 13587    False
# 13588     True
# 13589    False
# ...

# %% [markdown]
# Use a boolean Series to select the records for the pregnancies that ended in live birth.

# %%
live = df[df.outcome == 1]
len(live)
# Out:
# 9148

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 0 and 5 pounds (including both).  The result should be 1125.

# %%
len(live[(live.birthwgt_lb >= 0) & (live.birthwgt_lb <= 5)])
# Out:
# 1125

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[ (live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# Use <tt>birthord</tt> to select the records for first babies and others.  How many are there of each?

# %%
null = df.birthord.isnull().sum()
firsts = df[df.birthord == 1]
others = df[df.birthord > 1]
null, len(firsts), len(others)
# Out:
# (4445, 4413, 4735)

# %% [markdown]
# Compute the mean weight for first babies and others.

# %%
firsts.totalwgt_lb.mean()
# Out:
# 7.201094430437772

# %%
others.totalwgt_lb.mean()
# Out:
# 7.325855614973262

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
print firsts.prglngth.mean()
print others.prglngth.mean()
# Out:
# 38.6009517335
# 38.5229144667

# %%
diff_weeks = abs(firsts.prglngth.mean() - others.prglngth.mean()) # difference in weeks
diff_weeks
# Out:
# 0.07803726677754952

# %%
diff_hours = 7 * 24 * diff_weeks
diff_hours
# Out:
# 13.11026081862832
